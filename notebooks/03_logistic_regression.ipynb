# %% [markdown]
# # logistic regression

# %% [markdown]
# ## 1.import libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
    roc_curve
)

import joblib

# %% [markdown]
# ## 2.load data

# %%
from preprocessing_22 import load_data_scaled

(
    X_train,
    X_val,
    X_test,
    y_train,
    y_val,
    y_test,
    feature_names
) = load_data_scaled()

# %% [markdown]
# ## 3.train model

# %%
lr = LogisticRegression(
    max_iter=1000,
    random_state=42
)

lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# ## 4.predictions

# %%
# Evaluate on validation set
y_val_pred = lr.predict(X_val)

print(
    "Validation Accuracy:",
    accuracy_score(y_val, y_val_pred)
)
# Out:
# Validation Accuracy: 0.7534627167253292

# %%
# Evaluate on test set
y_pred = lr.predict(X_test)

y_prob = lr.predict_proba(X_test)[:, 1]

# %% [markdown]
# ## 5.matrics

# %%
# evaluation metrics
accuracy = accuracy_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)

recall = recall_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred)

auc = roc_auc_score(y_test, y_prob)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"ROC AUC  : {auc:.4f}")
# Out:
# Accuracy : 0.7492
# Precision: 0.6674
# Recall   : 0.5299
# F1 Score : 0.5907
# ROC AUC  : 0.8129

# %%
# classification matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82     80802
#            1       0.67      0.53      0.59     41934
#
#     accuracy                           0.75    122736
#    macro avg       0.72      0.70      0.70    122736
# weighted avg       0.74      0.75      0.74    122736

# %%
# confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %% [markdown]
# ## 6.roc curve

# %%
fpr, tpr, _ = roc_curve(
    y_test,
    y_prob
)

plt.figure(figsize=(7,5))

plt.plot(
    fpr,
    tpr,
    label=f"AUC = {auc:.4f}"
)

plt.plot(
    [0,1],
    [0,1],
    "--"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")

plt.legend()

plt.show()

# %%
joblib.dump(
    lr,
    "../models/higgs_logistic_regression.pkl"
)
# Out:
# ['../models/higgs_logistic_regression.pkl']
