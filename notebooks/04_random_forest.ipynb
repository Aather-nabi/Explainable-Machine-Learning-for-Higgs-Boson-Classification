# %% [markdown]
# # random forest

# %%
# import preprocessing module and reload it to reflect recent changes


from preprocessing_22 import load_data_unscaled
X_train, X_val, X_test, y_train, y_val, y_test, feature_names = load_data_unscaled()

# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
    roc_curve
)

import joblib

# %%
# print shapes of the datasets
print("Train:", X_train.shape)
print("Validation:", X_val.shape)
print("Test:", X_test.shape)
# Out:
# Train: (572766, 30)
# Validation: (122736, 30)
# Test: (122736, 30)

# %%
# initialize the random forest classifier with specified hyperparameters
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %% [markdown]
# ## predictions

# %%
# predict on the validation set
y_val_pred = rf.predict(X_val)

print(
    "Validation Accuracy:",
    accuracy_score(y_val, y_val_pred)
)
# Out:
# Validation Accuracy: 0.8416845913179507

# %%
# predict on the test set
y_pred = rf.predict(X_test)

y_prob = rf.predict_proba(X_test)[:, 1]

# %% [markdown]
# ## evaluation

# %%
# confusion matrix
cm = confusion_matrix(
    y_test,
    y_pred
)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Random Forest Confusion Matrix")

plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.tight_layout()

plt.savefig(
    "../results/plots/rf_confusion_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# evaluation metrics
accuracy = accuracy_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)

recall = recall_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred)

auc = roc_auc_score(y_test, y_prob)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"ROC AUC  : {auc:.4f}")
# Out:
# Accuracy : 0.8395
# Precision: 0.7939
# Recall   : 0.7163
# F1 Score : 0.7531
# ROC AUC  : 0.9054

# %%
# classification report
print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     80802
#            1       0.79      0.72      0.75     41934
#
#     accuracy                           0.84    122736
#    macro avg       0.83      0.81      0.82    122736
# weighted avg       0.84      0.84      0.84    122736

# %% [markdown]
# ## roc curve

# %%
joblib.dump(
    rf,
    "../models/higgs_random_forest.pkl"
)

print("Model saved successfully.")

# %%
fpr, tpr, _ = roc_curve(
    y_test,
    y_prob
)

plt.figure(figsize=(7,5))

plt.plot(
    fpr,
    tpr,
    label=f"AUC = {auc:.4f}"
)

plt.plot(
    [0,1],
    [0,1],
    "--"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("Random Forest ROC Curve")

plt.legend()

plt.tight_layout()

plt.savefig(
    "../results/plots/rf_roc_curve.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## overfittiong test

# %%
train_acc = rf.score(X_train, y_train)

val_acc = rf.score(X_val, y_val)

test_acc = rf.score(X_test, y_test)

print("Train:", train_acc)
print("Validation:", val_acc)
print("Test:", test_acc)
# Out:
# Train: 1.0
# Validation: 0.8416845913179507
# Test: 0.8395254855950984
